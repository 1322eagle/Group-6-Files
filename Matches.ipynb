# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ds=pd.read_csv(r"C:\Users\Lenovo\Desktop\New folder\matches.csv")
ds
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %%
ds.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
ds.tail()
# Out:
#         id  season           city      date                  team1  \
# 751  11347    2019         Mumbai  05/05/19  Kolkata Knight Riders
# 752  11412    2019        Chennai  07/05/19    Chennai Super Kings
# 753  11413    2019  Visakhapatnam  08/05/19    Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam  10/05/19         Delhi Capitals
# 755  11415    2019      Hyderabad  12/05/19         Mumbai Indians
#
#                    team2          toss_winner toss_decision  result  \
# 751       Mumbai Indians       Mumbai Indians         field  normal
# 752       Mumbai Indians  Chennai Super Kings           bat  normal
# 753       Delhi Capitals       Delhi Capitals         field  normal
# 754  Chennai Super Kings  Chennai Super Kings         field  normal
# 755  Chennai Super Kings       Mumbai Indians           bat  normal
#
#      dl_applied               winner  win_by_runs  win_by_wickets  \
# 751           0       Mumbai Indians            0               9
# ...

# %%
ds.describe()
# Out:
#                  id       season  dl_applied  win_by_runs  win_by_wickets
# count    756.000000   756.000000  756.000000   756.000000      756.000000
# mean    1792.178571  2013.444444    0.025132    13.283069        3.350529
# std     3464.478148     3.366895    0.156630    23.471144        3.387963
# min        1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%      189.750000  2011.000000    0.000000     0.000000        0.000000
# 50%      378.500000  2013.000000    0.000000     0.000000        4.000000
# 75%      567.250000  2016.000000    0.000000    19.000000        6.000000
# max    11415.000000  2019.000000    1.000000   146.000000       10.000000

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   season           756 non-null    int64
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %%
ds.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
for col in ds:
    print(col,len(ds[col].unique()))
# Out:
# id 756
# season 12
# city 33
# date 546
# team1 15
# team2 15
# toss_winner 15
# toss_decision 2
# result 3
# dl_applied 2
# winner 16
# win_by_runs 89
# win_by_wickets 11
# player_of_match 227
# venue 41
# umpire1 62
# umpire2 66
# umpire3 26

# %%
ds["city"].unique()
# Out:
# array(['Hyderabad', 'Pune', 'Rajkot', 'Indore', 'Bangalore', 'Mumbai',
#        'Kolkata', 'Delhi', 'Chandigarh', 'Kanpur', 'Jaipur', 'Chennai',
#        'Cape Town', 'Port Elizabeth', 'Durban', 'Centurion',
#        'East London', 'Johannesburg', 'Kimberley', 'Bloemfontein',
#        'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala', 'Kochi',
#        'Visakhapatnam', 'Raipur', 'Ranchi', 'Abu Dhabi', 'Sharjah', nan,
#        'Mohali', 'Bengaluru'], dtype=object)

# %%
ds.shape
# Out:
# (756, 18)

# %%
ds.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
ds[ds['umpire3'].isnull()]
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 632    633    2016      Bangalore  2016-05-24                Gujarat Lions
# 633    634    2016          Delhi  2016-05-25          Sunrisers Hyderabad
# 634    635    2016          Delhi  2016-05-27                Gujarat Lions
# 635    636    2016      Bangalore  2016-05-29          Sunrisers Hyderabad
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
#
# ...

# %%
ds['umpire3']=ds['umpire3'].fillna('digital')
ds['city']=ds['city'].fillna('data not avl.')
ds['player_of_match']=ds['player_of_match'].fillna('No data')
ds['winner']=ds['winner'].fillna('No data')
ds['umpire1']=ds['umpire1'].fillna('RJ Tucker')
ds['umpire2']=ds['umpire2'].fillna('HDPK Dharmasena')

ds['result'] = ds['result'].replace('no result', 'tie')

# %%
ds.isnull().sum()
# Out:
# id                 0
# season             0
# city               0
# date               0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# result             0
# dl_applied         0
# winner             0
# win_by_runs        0
# win_by_wickets     0
# player_of_match    0
# venue              0
# umpire1            0
# umpire2            0
# umpire3            0
# dtype: int64

# %%
ds["winner"].unique()
# Out:
# array(['Sunrisers Hyderabad', 'Rising Pune Supergiant',
#        'Kolkata Knight Riders', 'Kings XI Punjab',
#        'Royal Challengers Bangalore', 'Mumbai Indians',
#        'Delhi Daredevils', 'Gujarat Lions', 'Chennai Super Kings',
#        'Rajasthan Royals', 'Deccan Chargers', 'Pune Warriors',
#        'Kochi Tuskers Kerala', 'No data', 'Rising Pune Supergiants',
#        'Delhi Capitals'], dtype=object)

# %%
winner_count= ds['winner'].value_counts()
winner_count
# Out:
# winner
# Mumbai Indians                 109
# Chennai Super Kings            100
# Kolkata Knight Riders           92
# Royal Challengers Bangalore     84
# Kings XI Punjab                 82
# Rajasthan Royals                75
# Delhi Daredevils                67
# Sunrisers Hyderabad             58
# Deccan Chargers                 29
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Delhi Capitals                  10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# No data                          4
# Name: count, dtype: int64

# %%
winner_count.plot(kind="bar",color="orange")
plt.ylabel("No. of Time Wins")
plt.xlabel("Winner Team")
plt.xticks(rotation=90,color="black")
plt.show()

# %%
ds["player_of_match"].value_counts()
# Out:
# player_of_match
# CH Gayle          21
# AB de Villiers    20
# RG Sharma         17
# MS Dhoni          17
# DA Warner         17
#                   ..
# PD Collingwood     1
# NV Ojha            1
# AC Voges           1
# J Theron           1
# S Hetmyer          1
# Name: count, Length: 227, dtype: int64

# %%
ds.sort_values(by='win_by_runs',ascending=False)
# Out:
#       id  season       city        date                        team1  \
# 43    44    2017      Delhi  2017-05-06               Mumbai Indians
# 619  620    2016  Bangalore  2016-05-14  Royal Challengers Bangalore
# 59    60    2008  Bangalore  2008-04-18        Kolkata Knight Riders
# 556  557    2015  Bangalore  2015-05-06  Royal Challengers Bangalore
# 410  411    2013  Bangalore  2013-04-23  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 56    57    2017  Bangalore  2017-05-17          Sunrisers Hyderabad
# 363  364    2012    Chennai  2012-05-12             Delhi Daredevils
# 57    58    2017  Bangalore  2017-05-19        Kolkata Knight Riders
# 360  361    2012     Jaipur  2012-05-10             Rajasthan Royals
# 46    47    2017  Hyderabad  2017-05-08               Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
x=ds.groupby("season")['winner'].value_counts()
x.plot(kind="line")
plt.xticks(rotation=90)
# Out:
# (array([-20.,   0.,  20.,  40.,  60.,  80., 100., 120.]),
#  [Text(-20.0, 0, '(2017, Delhi Daredevils)'),
#   Text(0.0, 0, '(2008, Rajasthan Royals)'),
#   Text(20.0, 0, '(2010, Delhi Daredevils)'),
#   Text(40.0, 0, '(2012, Kings XI Punjab)'),
#   Text(60.0, 0, '(2014, Delhi Daredevils)'),
#   Text(80.0, 0, '(2017, Kolkata Knight Riders)'),
#   Text(100.0, 0, '(2019, Royal Challengers Bangalore)'),
#   Text(120.0, 0, '')])

# %%
ds['umpire1'].value_counts()
# Out:
# umpire1
# HDPK Dharmasena    73
# Asad Rauf          51
# S Ravi             49
# AK Chaudhary       43
# Aleem Dar          38
#                    ..
# Nanda Kishore       1
# SJA Taufel          1
# A Nanda Kishore     1
# SL Shastri          1
# Sundaram Ravi       1
# Name: count, Length: 62, dtype: int64

# %%
ds.groupby("season")['winner'].value_counts()
# Out:
# season  winner
# 2008    Rajasthan Royals               13
#         Kings XI Punjab                10
#         Chennai Super Kings             9
#         Mumbai Indians                  7
#         Delhi Daredevils                7
#                                        ..
# 2019    Kolkata Knight Riders           6
#         Sunrisers Hyderabad             6
#         Royal Challengers Bangalore     5
#         Rajasthan Royals                5
#         No data                         1
# Name: count, Length: 103, dtype: int64

# %%
rg=ds.groupby("team1")["result"].value_counts()
rg
# Out:
# team1                        result
# Chennai Super Kings          normal     89
# Deccan Chargers              normal     43
# Delhi Capitals               normal      6
# Delhi Daredevils             normal     69
#                              tie         3
# Gujarat Lions                normal     13
#                              tie         1
# Kings XI Punjab              normal     90
#                              tie         1
# Kochi Tuskers Kerala         normal      7
# Kolkata Knight Riders        normal     82
#                              tie         1
# Mumbai Indians               normal    100
#                              tie         1
# Pune Warriors                normal     20
# Rajasthan Royals             normal     64
#                              tie         3
# Rising Pune Supergiant       normal      8
# Rising Pune Supergiants      normal      7
# Royal Challengers Bangalore  normal     82
#                              tie         3
# ...

# %%
fig, ax = plt.subplots(figsize=(8, 6))

colors=['#474440',"#eb44e8"]
rg_unstacked.plot(kind='bar', stacked=True, ax=ax,color=colors)
ax.set_xlabel('Teams ')
ax.set_ylabel('Number of Matches')
ax.set_title('Number of Normal Wins and Ties for Teams in group 1')

plt.xticks(rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %%
df=ds.groupby("team2")["result"].value_counts()
df_unstacked = df.unstack(level=-1)
fig, ax = plt.subplots(figsize=(8, 6))

colors=["#9080ff","#ffb400"]
df_unstacked.plot(kind='bar', stacked=True, ax=ax,color=colors)
ax.set_xlabel('Teams ')
ax.set_ylabel('Number of Matches')
ax.set_title('Number of Normal Wins and Ties for Teams in group 2')

plt.xticks(rotation=45, ha='right')

plt.tight_layout()
plt.show()

# %%
ds.groupby("winner")["win_by_runs"].value_counts()
# Out:
# winner               win_by_runs
# Chennai Super Kings  0              48
#                      38              3
#                      18              3
#                      13              3
#                      24              3
#                                     ..
# Sunrisers Hyderabad  30              1
#                      26              1
#                      23              1
#                      20              1
#                      118             1
# Name: count, Length: 277, dtype: int64

# %%
win_counts = ds['winner'].value_counts()

# Plotting the bar plot
plt.figure(figsize=(10, 6))
win_counts.plot(kind='bar')
plt.xlabel('Teams')
plt.ylabel('Number of Wins')
plt.title('Number of Wins by Each Team')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
gh=ds.groupby('season')['win_by_runs'].value_counts()
gh_unstacked = gh.unstack(level=-1)
fig, ax = plt.subplots(figsize=(8, 6))

colors=["#e27c7c","#599e94"]
gh_unstacked.plot(kind='bar', stacked=True, ax=ax,color=colors)
ax.set_xlabel('Teams ')
ax.set_ylabel('Number of Matches')
ax.set_title('Number of Normal Wins and Ties for Teams in group 2')

plt.xticks(rotation=45, ha='right')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_5944\2557808681.py:13: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all axes decorations.
#   plt.tight_layout()

# %%
pt=ds.groupby('season')['win_by_wickets'].value_counts()
pt_unstacked = pt.unstack(level=-1)
fig, ax = plt.subplots(figsize=(8, 6))

colors=["#bd7ebe","#5ad45a"]
pt_unstacked.plot(kind='bar', stacked=True, ax=ax,color=colors)
ax.set_xlabel('Teams ')
ax.set_ylabel('Number of Matches')
ax.set_title('Number of Normal Wins and Ties for Teams in group 2')

plt.xticks(rotation=45, ha='right')

plt.tight_layout()
plt.show()
