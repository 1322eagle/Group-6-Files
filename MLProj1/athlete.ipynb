# %%
# Importing necessary libraries
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
athlete = pd.read_csv(r"D:\Project\ALL CSV\athlete_events.csv")

# %%
# Display the first few rows of the dataframe
print(athlete.head())
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
# Check dimensions of the dataset
print("Dataset dimensions:", athlete.shape)
# Out:
# Dataset dimensions: (271116, 15)

# %%
# View data types of each column
print("\nData types:")
print(athlete.dtypes)
# Out:
# Data types:
# ID          int64
# Name       object
# Sex        object
# Age       float64
# Height    float64
# Weight    float64
# Team       object
# NOC        object
# Games      object
# Year        int64
# Season     object
# City       object
# Sport      object
# Event      object
# Medal      object
# dtype: object

# %%
athlete
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
# Check for missing values
print(athlete.isnull().sum())
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# dtype: int64

# %%
# Calculate basic summary statistics for numerical columns
print(athlete.describe())
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %%
# View the last few rows of the dataset
athlete.tail()
# Out:
#             ID                Name Sex   Age  Height  Weight      Team  NOC  \
# 271111  135569          Andrzej ya   M  29.0   179.0    89.0  Poland-1  POL
# 271112  135570            Piotr ya   M  27.0   176.0    59.0    Poland  POL
# 271113  135570            Piotr ya   M  27.0   176.0    59.0    Poland  POL
# 271114  135571  Tomasz Ireneusz ya   M  30.0   185.0    96.0    Poland  POL
# 271115  135571  Tomasz Ireneusz ya   M  34.0   185.0    96.0    Poland  POL
#
#               Games  Year  Season            City        Sport  \
# 271111  1976 Winter  1976  Winter       Innsbruck         Luge
# 271112  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271113  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271114  1998 Winter  1998  Winter          Nagano    Bobsleigh
# 271115  2002 Winter  2002  Winter  Salt Lake City    Bobsleigh
#
#                                            Event Medal
# 271111                Luge Mixed (Men)'s Doubles   NaN
# ...

# %%
# View data types and non-null counts of each column
athlete.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
sns.countplot(x='Year', hue='Medal', data=athlete)
plt.xlabel('Year')
plt.ylabel('Count')
plt.legend(title='Medal', loc='upper right')
plt.tight_layout()
plt.show()

# %%
sns.histplot(data=athlete, x='Age', bins=20, kde=True)
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()
# Out:
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
athlete= athlete[["Name", "Team", "Age", "Event", "Year", "Sport", "Medal"]]
athlete
# Out:
#                                        Name            Team   Age  \
# 3                      Edgar Lindenau Aabye  Denmark/Sweden  34.0
# 37                     Arvo Ossian Aaltonen         Finland  30.0
# 38                     Arvo Ossian Aaltonen         Finland  30.0
# 40                 Juhamatti Tapio Aaltonen         Finland  28.0
# 41                  Paavo Johannes Aaltonen         Finland  28.0
# ...                                     ...             ...   ...
# 271078  Galina Ivanovna Zybina (-Fyodorova)    Soviet Union  25.0
# 271080  Galina Ivanovna Zybina (-Fyodorova)    Soviet Union  33.0
# 271082                         Bogusaw Zych          Poland  28.0
# 271102            Olesya Nikolayevna Zykina          Russia  19.0
# 271103            Olesya Nikolayevna Zykina          Russia  23.0
#
#                                          Event  Year       Sport   Medal
# 3                  Tug-Of-War Men's Tug-Of-War  1900  Tug-Of-War    Gold
# ...

# %%
sns.lmplot(x='Age',y='Year',data=teams,fit_reg=True, ci=None)
# Out:
# /Users/samridhisharma/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
athlete.plot.hist(y="Year")
# Out:
# <Axes: ylabel='Frequency'>

# %%
athlete[athlete.isnull().any(axis=1)]
# Out:
#                             Name         Team   Age  \
# 0                      A Dijiang        China  24.0
# 1                       A Lamusi        China  23.0
# 2            Gunnar Nielsen Aaby      Denmark  24.0
# 4       Christine Jacoba Aaftink  Netherlands  21.0
# 5       Christine Jacoba Aaftink  Netherlands  21.0
# ...                          ...          ...   ...
# 271111                Andrzej ya     Poland-1  29.0
# 271112                  Piotr ya       Poland  27.0
# 271113                  Piotr ya       Poland  27.0
# 271114        Tomasz Ireneusz ya       Poland  30.0
# 271115        Tomasz Ireneusz ya       Poland  34.0
#
#                                            Event  Year          Sport Medal
# 0                    Basketball Men's Basketball  1992     Basketball   NaN
# 1                   Judo Men's Extra-Lightweight  2012           Judo   NaN
# 2                        Football Men's Football  1920       Football   NaN
# ...

# %%
athlete= athlete.dropna()

# %%
athlete
# Out:
#                                        Name            Team   Age  \
# 3                      Edgar Lindenau Aabye  Denmark/Sweden  34.0
# 37                     Arvo Ossian Aaltonen         Finland  30.0
# 38                     Arvo Ossian Aaltonen         Finland  30.0
# 40                 Juhamatti Tapio Aaltonen         Finland  28.0
# 41                  Paavo Johannes Aaltonen         Finland  28.0
# ...                                     ...             ...   ...
# 271078  Galina Ivanovna Zybina (-Fyodorova)    Soviet Union  25.0
# 271080  Galina Ivanovna Zybina (-Fyodorova)    Soviet Union  33.0
# 271082                         Bogusaw Zych          Poland  28.0
# 271102            Olesya Nikolayevna Zykina          Russia  19.0
# 271103            Olesya Nikolayevna Zykina          Russia  23.0
#
#                                          Event  Year       Sport   Medal
# 3                  Tug-Of-War Men's Tug-Of-War  1900  Tug-Of-War    Gold
# ...

# %%
train =athlete[athlete["Year"]<2012].copy()
test = athlete[athlete["Year"]>=2012].copy()

# %%
athlete.shape
# Out:
# (39051, 7)

# %%
test.shape
# Out:
# (31499, 15)

# %%
from sklearn.linear_model import LinearRegression

reg = LinearRegression()

# %%
predictors = ["Age"]
target ="Year"

# %%
reg.fit(train[predictors], train["Year"])

# %%
predictions = reg.predict(test[predictors])

# %%
test["predictions"] = predictions

# %%
test
# Out:
#                                          Name        Team   Age  \
# 40                   Juhamatti Tapio Aaltonen     Finland  28.0
# 158                         Giovanni Abagnale       Italy  21.0
# 161                         Patimat Abakarova  Azerbaijan  21.0
# 174                                 Luc Abalo      France  27.0
# 175                                 Luc Abalo      France  31.0
# ...                                       ...         ...   ...
# 270440                            Zou Shiming       China  31.0
# 270609             Aleksandr Yuryevich Zubkov    Russia-1  39.0
# 270610             Aleksandr Yuryevich Zubkov    Russia-1  39.0
# 270939  Anastasiya Valeryevna Zuyeva-Fesikova      Russia  22.0
# 271019                         Martin Zwicker     Germany  29.0
#
#                                          Event  Year       Sport   Medal  \
# 40                 Ice Hockey Men's Ice Hockey  2014  Ice Hockey  Bronze
# ...

# %%
test.loc[test["predictions"]< 0, "predictions"]=0

# %%
test["predictions"]= test["predictions"].round()

# %%
test
# Out:
#                                          Name        Team   Age  \
# 40                   Juhamatti Tapio Aaltonen     Finland  28.0
# 158                         Giovanni Abagnale       Italy  21.0
# 161                         Patimat Abakarova  Azerbaijan  21.0
# 174                                 Luc Abalo      France  27.0
# 175                                 Luc Abalo      France  31.0
# ...                                       ...         ...   ...
# 270440                            Zou Shiming       China  31.0
# 270609             Aleksandr Yuryevich Zubkov    Russia-1  39.0
# 270610             Aleksandr Yuryevich Zubkov    Russia-1  39.0
# 270939  Anastasiya Valeryevna Zuyeva-Fesikova      Russia  22.0
# 271019                         Martin Zwicker     Germany  29.0
#
#                                          Event  Year       Sport   Medal  \
# 40                 Ice Hockey Men's Ice Hockey  2014  Ice Hockey  Bronze
# ...

# %%
from sklearn.metrics import mean_absolute_error

error= mean_absolute_error(test["Year"], test["predictions"])

# %%
error
# Out:
# 44.358254768691076

# %%
teams.describe()["Year"]
# Out:
# count    271116.000000
# mean       1978.378480
# std          29.877632
# min        1896.000000
# 25%        1960.000000
# 50%        1988.000000
# 75%        2002.000000
# max        2016.000000
# Name: Year, dtype: float64

# %%
test[test["Team"]== "United States"]
# Out:
#                              Name           Team   Age  \
# 278                 Jeremy Abbott  United States  28.0
# 1514         Rachael Alexis Adams  United States  26.0
# 1844       Nathan Ghar-Jun Adrian  United States  23.0
# 1845       Nathan Ghar-Jun Adrian  United States  23.0
# 1846       Nathan Ghar-Jun Adrian  United States  23.0
# ...                           ...            ...   ...
# 262050                 David Wise  United States  23.0
# 263025              Kelsi Worrell  United States  22.0
# 263118  Dagmara Wozniak (Woniak-)  United States  28.0
# 263504                Jacob Wukie  United States  26.0
# 267209       Mariel Leigh Zagunis  United States  31.0
#
#                                                 Event  Year             Sport  \
# 278                         Figure Skating Mixed Team  2014    Figure Skating
# 1514                    Volleyball Women's Volleyball  2016        Volleyball
# ...

# %%
test[test["Team"]=="India"]
# Out:
#                                   Name   Team   Age  \
# 60361                   Yogeshwar Dutt  India  29.0
# 123303    Mangte Chungneijang Mary Kom  India  29.0
# 128928            Sushil Kumar Solanki  India  29.0
# 128930                     Vijay Kumar  India  26.0
# 147624                    Sakshi Malik  India  23.0
# 168204                    Gagan Narang  India  29.0
# 169313                    Saina Nehwal  India  22.0
# 220929  Pusarla Venkata "P. V." Sindhu  India  21.0
#
#                                               Event  Year      Sport   Medal  \
# 60361        Wrestling Men's Lightweight, Freestyle  2012  Wrestling  Bronze
# 123303                     Boxing Women's Flyweight  2012     Boxing  Bronze
# 128928      Wrestling Men's Welterweight, Freestyle  2012  Wrestling  Silver
# 128930  Shooting Men's Rapid-Fire Pistol, 25 metres  2012   Shooting  Silver
# 147624     Wrestling Women's Lightweight, Freestyle  2016  Wrestling  Bronze
# ...

# %%
 errors = (test["Year"]- test["predictions"]).abs()

# %%
errors
# Out:
# 40        45.0
# 158       43.0
# 161       43.0
# 174       43.0
# 175       49.0
#           ...
# 270440    45.0
# 270609    52.0
# 270610    52.0
# 270939    40.0
# 271019    48.0
# Length: 4561, dtype: float64

# %%
error_by_team = errors.groupby(test["Team"]).mean()

# %%
error_by_team
# Out:
# Team
# Afghanistan        42.000000
# Algeria            45.000000
# Argentina          45.731707
# Armenia            42.571429
# Australia          43.417085
#                      ...
# United States-1    47.636364
# United States-2    45.750000
# Uzbekistan         44.750000
# Venezuela          43.000000
# Vietnam            55.000000
# Length: 122, dtype: float64

# %%
medals_by_team = test["Year"].groupby(test["Team"]).mean()

# %%
error_ratio = error_by_team / medals_by_team

# %%
error_ratio
# Out:
# Team
# Afghanistan        0.020875
# Algeria            0.022336
# Argentina          0.022705
# Armenia            0.021135
# Australia          0.021561
#                      ...
# United States-1    0.023657
# United States-2    0.022710
# Uzbekistan         0.022206
# Venezuela          0.021340
# Vietnam            0.027282
# Length: 122, dtype: float64

# %%
error_ratio[~pd.isnull(error_ratio)]
# Out:
# Team
# Afghanistan        0.020875
# Algeria            0.022336
# Argentina          0.022705
# Armenia            0.021135
# Australia          0.021561
#                      ...
# United States-1    0.023657
# United States-2    0.022710
# Uzbekistan         0.022206
# Venezuela          0.021340
# Vietnam            0.027282
# Length: 122, dtype: float64

# %%
import numpy as np
error_ratio = error_ratio[np.isfinite(error_ratio)]

# %%
error_ratio
# Out:
# Team
# Afghanistan        0.020875
# Algeria            0.022336
# Argentina          0.022705
# Armenia            0.021135
# Australia          0.021561
#                      ...
# United States-1    0.023657
# United States-2    0.022710
# Uzbekistan         0.022206
# Venezuela          0.021340
# Vietnam            0.027282
# Length: 122, dtype: float64

# %%
error_ratio.plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
 error_ratio.sort_values()
# Out:
# Team
# Botswana                       0.018390
# Guatemala                      0.019384
# Moldova                        0.019384
# Gabon                          0.019881
# Japan-1                        0.019881
#                                  ...
# Estonia                        0.024073
# Spain-2                        0.024802
# Kuwait                         0.026839
# Vietnam                        0.027282
# Individual Olympic Athletes    0.030258
# Length: 122, dtype: float64
